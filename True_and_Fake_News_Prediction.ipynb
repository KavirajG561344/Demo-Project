# %% [markdown]
# <a href="https://colab.research.google.com/github/KavirajG561344/Demo-Project/blob/main/True_and_Fake_News_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# True and Fake News Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
#importing the required libraries for the Analysis of the project.

# %%
Train=pd.read_csv('/content/drive/MyDrive/Fake news prediction /train.csv')
##import necessary libraries and load dataset

# %%
Test=pd.read_csv('/content/drive/MyDrive/Fake news prediction /test.csv')
##import necessary libraries and load dataset

# %% [markdown]
# # Data Structure and Content

# %%
Train.shape
# shape function Helps us identify how many rows and columns we have acoording to our data set
# Out:
# (20800, 5)

# %%
Test.shape
# shape function Helps us identify how many rows and columns we have acoording to our data set.
# Out:
# (5200, 4)

# %%
Train.info()
#display the information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
Train.isnull().sum()
#display number of missing values of each column
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %%
Train.describe()
#display descriptive statistics
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
Train.head()
#display first few rows of the datasets
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# 1.Removing the nullvalues

# %%
Train=Train.fillna('')
#Replace the missing values in the Train dataset with a space (' ')

# %%
Train.isnull().sum()
#Replace the missing values in the Test dataset with a space (' ')
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
Test.info()
#display information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5200 non-null   int64
#  1   title   5078 non-null   object
#  2   author  4697 non-null   object
#  3   text    5193 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 162.6+ KB

# %%
Test.isnull().sum()
#display number of missing values of each column
# Out:
# id          0
# title     122
# author    503
# text        7
# dtype: int64

# %%
Test.describe()
#display descriptive statistics
# Out:
#                  id
# count   5200.000000
# mean   23399.500000
# std     1501.255031
# min    20800.000000
# 25%    22099.750000
# 50%    23399.500000
# 75%    24699.250000
# max    25999.000000

# %%
Test.head()
#display first few rows of the datasets
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
Train['subject']=Train['author']+Train['title']
# Create a new column 'subject' by concatenating the 'author' and 'title' columns with a space in between

# %%
Train.head()
#display first few rows of the datasets
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject
# 0  Darrell LucusHouse Dem Aide: We Didn’t Even Se...
# 1  Daniel J. FlynnFLYNN: Hillary Clinton, Big Wom...
# 2  Consortiumnews.comWhy the Truth Might Get You ...
# 3  Jessica Purkiss15 Civilians Killed In Single U...
# 4  Howard PortnoyIranian woman jailed for fiction...

# %%
Test.head()
#display first few rows of the datasets
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %% [markdown]
# # Tokenization

# %%
import nltk
nltk.download('punkt')
# Download the Punkt tokenizer models for tokenization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
Train['tokens']=Train['subject'].apply(word_tokenize)
# Tokenize the 'subject' column and create a new column 'tokens'

# %%
Train.head()
#display first few rows of the datasets

# %% [markdown]
# 3.Lowercasing the text

# %%
Train['subject']=Train['subject'].str.lower()
# Convert all text in the 'subject' column to lowercase

# %%
Train.head()
#display first few rows of the datasets

# %% [markdown]
# 4.Removal of Punctuation

# %%
Train['subject']=Train['subject'].str.replace('[^\w\s]',' ')
# Remove all punctuation marks from the 'subject' column

# %%
Train.head()
#display first few rows of the datasets

# %%
# !pip install nltk # Make sure NLTK is installed
import nltk
nltk.download('punkt') # Download the 'punkt' resource
from nltk.tokenize import word_tokenize
train['tokens'] = train['subject'].apply(word_tokenize)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
Train.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject
# 0  Darrell LucusHouse Dem Aide: We Didn’t Even Se...
# 1  Daniel J. FlynnFLYNN: Hillary Clinton, Big Wom...
# 2  Consortiumnews.comWhy the Truth Might Get You ...
# 3  Jessica Purkiss15 Civilians Killed In Single U...
# 4  Howard PortnoyIranian woman jailed for fiction...

# %%
Train['subject']=Train['subject'].str.lower()

# %%
Train.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject
# 0  darrell lucushouse dem aide: we didn’t even se...
# 1  daniel j. flynnflynn: hillary clinton, big wom...
# 2  consortiumnews.comwhy the truth might get you ...
# 3  jessica purkiss15 civilians killed in single u...
# 4  howard portnoyiranian woman jailed for fiction...

# %% [markdown]
# 4.Removal of Punctuation

# %%
Train['subject']=Train['subject'].str.replace('[^\w\s]','')
# Remove all punctuation marks from the 'subject' column

# %%
Train.head()
#display first few rows of the datasets
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject
# 0  darrel lucushous dem aide: we didn’t even see ...
# 1  daniel j. flynnflynn: hillari clinton, big wom...
# 2  consortiumnews.comwhi the truth might get you ...
# 3  jessica purkiss15 civilian kill in singl us ai...
# 4  howard portnoyiranian woman jail for fiction u...

# %% [markdown]
# 5.Removal of stop words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sw=set(nltk.corpus.stopwords.words('english'))
print(sw)
# Out:
# {'should', 'do', 'aren', "doesn't", 'with', 'ourselves', 'some', 'no', 'for', 'why', 'her', 'had', 'what', 'being', 'off', 'my', 'd', "you'd", 'than', 'shan', "hadn't", "shan't", 'before', 'when', 'through', 'have', 'are', 'so', "couldn't", 'having', 'them', 'wasn', 'weren', 'itself', 'hadn', 'up', 'now', 'and', "won't", "wouldn't", 'those', 'against', "that'll", 'been', 'i', 'ours', "don't", 'of', 'doesn', 'more', 'because', 'she', 'their', 'has', "she's", 'further', "wasn't", 'an', 'his', 'he', 'very', 'wouldn', 'ain', 'won', 'your', "needn't", 'am', 'o', 'whom', 'were', 'don', 'in', 'that', 'under', 'where', 'ma', 'how', 'the', "shouldn't", 'here', 'it', 'myself', 'its', 'out', 'herself', 'between', 'you', 'then', 'same', 'me', 'theirs', "mightn't", 'a', 've', 'will', 'any', 'y', 'isn', 'couldn', "you've", 'once', 'yours', "weren't", "it's", 'at', 'mightn', 'after', 'while', 'mustn', 'him', 'is', 'both', 'these', 'too', 'few', "should've", 'yourselves', 'be', 'only', 'hers', 'below', 'from', 'not', 're', "you're", "you'll", 'as', 'to', 'other', 'this', 'each', 'there', 'needn', 'which', 'most', "haven't", 't', 'until', 'nor', 'didn', 'm', 'themselves', 'they', 'again', 'll', 'our', 'yourself', 'but', 'own', 'can', 's', 'down', 'did', 'was', 'during', 'we', "isn't", 'if', 'does', 'by', 'just', "mustn't", 'hasn', 'himself', 'doing', 'above', "hasn't", 'all', 'about', "aren't", "didn't", 'into', 'who', 'on', 'or', 'such', 'haven', 'over', 'shouldn'}

# %%
Train['subject'] = Train['subject'].apply(lambda x: ' '.join([word for word in x.split() if word not in sw]))
# Here we try to remove the stopwords by adding only the words which are not in the SW stopword set.

# %%
Train.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject
# 0  darrell lucushouse dem aide: we didn’t even se...
# 1  daniel j. flynnflynn: hillary clinton, big wom...
# 2  consortiumnews.comwhy the truth might get you ...
# 3  jessica purkiss15 civilians killed in single u...
# 4  howard portnoyiranian woman jailed for fiction...

# %% [markdown]
# 6.Stemming or Lammatization

# %%
from nltk.stem import PorterStemmer
# Import the PorterStemmer class for stemming

# %%
Stemmer=PorterStemmer()
#To Apply Stemming or Lemmatization :        stemmer = PorterStemmer()
Train['subject'] = Train['subject'].apply(lambda x: ' '.join([Stemmer.stem(word) for word in x.split()]))
# Stemming is the simple process of reducing the words to their root forms

# %%
Train.head()
#display first few rows of the datasets
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              subject
# 0  darrel lucushous dem aide: we didn’t even see ...
# 1  daniel j. flynnflynn: hillari clinton, big wom...
# 2  consortiumnews.comwhi the truth might get you ...
# 3  jessica purkiss15 civilian kill in singl us ai...
# 4  howard portnoyiranian woman jail for fiction u...

# %% [markdown]
# **Vectorisation**

# %%
x=Train['subject']
y=Train['label']
# Assign the 'subject' column to variable x (features) and the 'label' column to variable y (target)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Import the TfidfVectorizer class for vectorizing text data

# %%
Vt=TfidfVectorizer()
Vt.fit(x)
# Fit the TfidfVectorizer on the 'subject' column of the Train dataset
# Out:
# TfidfVectorizer()

# %%
TfidfVectorizer()
# Out:
# TfidfVectorizer()

# %% [markdown]
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
x.head()
#display first few rows of the datasets
# Out:
# 0    darrel lucushous dem aide: we didn’t even see ...
# 1    daniel j. flynnflynn: hillari clinton, big wom...
# 2    consortiumnews.comwhi the truth might get you ...
# 3    jessica purkiss15 civilian kill in singl us ai...
# 4    howard portnoyiranian woman jail for fiction u...
# Name: subject, dtype: object

# %%
x=Vt.transform(x)
# Transform the 'subject' column of the Train dataset using the fitted TfidfVectorizer

# %%
print(x)
# Print the transformed data
# Out:
# 0        darrel lucushous dem aide: we didn’t even see ...
# 1        daniel j. flynnflynn: hillari clinton, big wom...
# 2        consortiumnews.comwhi the truth might get you ...
# 3        jessica purkiss15 civilian kill in singl us ai...
# 4        howard portnoyiranian woman jail for fiction u...
#                                ...
# 20795    jerom hudsonrapp t.i.: trump a ’poster child f...
# 20796    benjamin hoffmann.f.l. playoffs: schedule, mat...
# 20797    michael j. de la merc and rachel abramsmacy’ i...
# 20798    alex ansarynato, russia to hold parallel exerc...
# 20799                 david swansonwhat keep the f-35 aliv
# Name: subject, Length: 20800, dtype: object

# %%
# For building the machine learning models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# For evaluating the models using the metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection  import cross_val_score as CVS
from sklearn.metrics import classification_report

# %%
xTrain,xTest,yTrain,yTest=train_test_split(x,y,test_size=0.2,stratify=y,random_state=42)
# Split the data into training and testing sets

# %%
Model=LogisticRegression()
# Create a Logistic Regression model

# %%
Model.fit(xTrain,yTrain)
# Fit the Logistic Regression model on the training data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-ba56d213d03b> in <cell line: 1>()
# ----> 1 Model.fit(xTrain,yTrain)
#       2 # Fit the Logistic Regression model on the training data
#       3
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620                 y = check_array(y, input_name="y", **check_y_params)
#     621             else:
# --> 622                 X, y = check_X_y(X, y, **check_params)
#     623             out = X, y
#     624
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1144         )
#    1145
# -> 1146     X = check_array(
#    1147         X,
#    1148         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
# --> 915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     951         """
#     952         values = self._values
# --> 953         arr = np.asarray(values, dtype=dtype)
#     954         if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#     955             arr = arr.view()
#
# ValueError: could not convert string to float: 'yamich alcindorthousand of mourner celebr gwen ifill’ tenac and grace - the new york time'

# %%
LogisticRegression()
# Out:
# LogisticRegression()

# %% [markdown]
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
ytrpredict=Model.predict(xTrain)
# Make predictions on the training data using the trained Logistic Regression model

# %%
accuracy=accuracy_score(yTrain,ytrpredict)
precision=precision_score(yTrain,ytrpredict)
recall=recall_score(yTrain,ytrpredict)
f1=f1_score(yTrain,ytrpredict)

print('Training Accuracy:',accuracy)
print('Training Precision:',precision)
print('Training Recall:',recall)
print('Training F1 Score:',f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-5fefe041c874> in <cell line: 1>()
# ----> 1 accuracy=accuracy_score(yTrain,ytrpredict)
#       2 precision=precision_score(yTrain,ytrpredict)
#       3 recall=recall_score(yTrain,ytrpredict)
#       4 f1=f1_score(yTrain,ytrpredict)
#       5
#
# NameError: name 'ytrpredict' is not defined

# %%
accuracy =accuracy_score(yTrain,ytrpredict)
precision = precision_score(yTrain, ytrpredict)
recall = recall_score(yTrain, ytrpredict)
f1 = f1_score(yTrain, ytrpredict)

print(' Training Accuracy:', accuracy)
print(' Training Precision:', precision)
print(' Training Recall:', recall)
print('Training F1 Score:',f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-053bdfee5e2b> in <cell line: 1>()
# ----> 1 accuracy =accuracy_score(yTrain,ytrpredict)
#       2 precision = precision_score(yTrain, ytrpredict)
#       3 recall = recall_score(yTrain, ytrpredict)
#       4 f1 = f1_score(yTrain, ytrpredict)
#       5
#
# NameError: name 'ytrpredict' is not defined

# %%
Yttpredict=Model.predict(xTest)
# Make predictions on the testing data using the trained Logistic Regression model
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-151-6c811f586957> in <cell line: 1>()
# ----> 1 Yttpredict=Model.predict(xTest)
#       2 # Make predictions on the testing data using the trained Logistic Regression model
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     449         """
#     450         xp, _ = get_namespace(X)
# --> 451         scores = self.decision_function(X)
#     452         if len(scores.shape) == 1:
#     453             indices = xp.astype(scores > 0, int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     427             this class would be predicted.
#     428         """
# --> 429         check_is_fitted(self)
#     430         xp, _ = get_namespace(X)
#     431
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1459
#    1460     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1461         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1462
#    1463
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
accuracy =accuracy_score(yTest,Yttpredict)
precision = precision_score(yTest, Yttpredict)
recall = recall_score(yTest, Yttpredict)
f1 = f1_score(yTest, Yttpredict)

print(' Testing Accuracy:', accuracy)
print(' Testing Precision:', precision)
print(' Testing Recall:', recall)
print('Testing F1 Score:',f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-e44b9c68a11b> in <cell line: 1>()
# ----> 1 accuracy =accuracy_score(yTest,Yttpredict)
#       2 precision = precision_score(yTest, Yttpredict)
#       3 recall = recall_score(yTest, Yttpredict)
#       4 f1 = f1_score(yTest, Yttpredict)
#       5
#
# NameError: name 'Yttpredict' is not defined

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Import necessary libraries for confusion matrix

# %%
# Generate the confusion matrix
cm = confusion_matrix(yTrain,ytrpredict)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-152-29242fd0c04d> in <cell line: 2>()
#       1 # Generate the confusion matrix
# ----> 2 cm = confusion_matrix(yTrain,ytrpredict)
#       3
#       4 # Display the confusion matrix
#       5 disp = ConfusionMatrixDisplay(confusion_matrix=cm)
#
# NameError: name 'ytrpredict' is not defined

# %%
# Generate the confusion matrix
cm = confusion_matrix(yTest,Yttpredict)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-e214d1a82f5a> in <cell line: 2>()
#       1 # Generate the confusion matrix
# ----> 2 cm = confusion_matrix(yTest,Yttpredict)
#       3
#       4 # Display the confusion matrix
#       5 disp = ConfusionMatrixDisplay(confusion_matrix=cm)
#
# NameError: name 'Yttpredict' is not defined

# %% [markdown]
# **saving the model**

# %%
import pickle
# Import the pickle module for serializing and deserializing Python object
